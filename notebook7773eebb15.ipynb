# %% [markdown]
# <a href="https://www.kaggle.com/code/savageopress12345/notebook7773eebb15?scriptVersionId=99476671" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

from prophet.plot import plot_plotly, plot_components_plotly
from prophet import Prophet
from plotly.offline import plot, iplot, init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/easella/csvz/main/convertcsv.csv')
df.dropna(inplace= True)
df.reset_index(drop=True, inplace=True)

# %%
df=df[["Date","Length"]]
df.head()
# Out:
#             Date  Length
# 0  June 30, 2022     115
# 1  June 29, 2022     136
# 2  June 28, 2022     109
# 3  June 27, 2022     121
# 4  June 26, 2022     112

# %%
df.columns = ['ds','y']

# %%
df['ds'] = pd.to_datetime(df['ds'])
df.tail()
# Out:
#            ds   y
# 49 2022-05-12  70
# 50 2022-05-11  73
# 51 2022-05-10  86
# 52 2022-05-09  87
# 53 2022-05-08  76

# %%
df.plot(x='ds',y='y',figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
train = df.iloc[:len(df)]
test = df.iloc[len(df):]

# %%
m = Prophet()
m.fit(train)
future = m.make_future_dataframe(periods=365) #MS for monthly, H for hourly
forecast = m.predict(future)
# Out:
# Initial log joint probability = -19.034
# Iteration  1. Log joint probability =    65.1762. Improved by 84.2102.
# Iteration  2. Log joint probability =    94.5171. Improved by 29.3408.
# Iteration  3. Log joint probability =    96.0174. Improved by 1.50036.
# Iteration  4. Log joint probability =    97.3171. Improved by 1.29966.
# Iteration  5. Log joint probability =    97.3314. Improved by 0.0142803.
# Iteration  6. Log joint probability =    97.4456. Improved by 0.11425.
# Iteration  7. Log joint probability =    97.7412. Improved by 0.295629.
# Iteration  8. Log joint probability =    97.7698. Improved by 0.0285822.
# Iteration  9. Log joint probability =    97.8474. Improved by 0.0775832.
# Iteration 10. Log joint probability =    97.9135. Improved by 0.0661055.
# Iteration 11. Log joint probability =    98.1658. Improved by 0.252275.
# Iteration 12. Log joint probability =    98.3923. Improved by 0.226559.
# ...

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 414 2023-06-26  498.813039  479.233402  517.434564
# 415 2023-06-27  493.812516  473.221950  513.998234
# 416 2023-06-28  496.435947  476.533309  515.507023
# 417 2023-06-29  494.310045  475.727093  514.456667
# 418 2023-06-30  496.240151  476.904121  515.378352

# %%
plot_plotly(m ,forecast)

# %%
import pandas as pd
from datetime import datetime


# Import pandas library

 
# initialize list elements
data = [4.85,4.05,4.33,4.3,4.65,4.67,4.65,4.42,3.95,3.67,4.31,4.13,4.54,4.88,4.15,4.35,4.83,4.62,5.03,4.63,4.28,4.38,4.54,5.06,5.31,4.63]

# Create the pandas DataFrame with column name is provided explicitly

 
# print dataframe.

datelist = pd.date_range(datetime.today(), periods=18).strftime('%m-%d-%Y')
runs = pd.DataFrame(data, datelist,columns=['Runs'])
runs.rename(columns={ runs.columns[0]: "whatever" })



datelist


runs
# Out:
#             Runs
# 06-27-2022  4.85
# 06-28-2022  4.05
# 06-29-2022  4.33
# 06-30-2022  4.30
# 07-01-2022  4.65
# 07-02-2022  4.67
# 07-03-2022  4.65
# 07-04-2022  4.42
# 07-05-2022  3.95
# 07-06-2022  3.67
# 07-07-2022  4.31
# 07-08-2022  4.13
# 07-09-2022  4.54
# 07-10-2022  4.88
# 07-11-2022  4.15
# 07-12-2022  4.35
# 07-13-2022  4.83
# 07-14-2022  4.62

# %%
import pandas as pd
redsdata=pd.read_csv("my_html_data_to_csv.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_34/2085116210.py in <module>
#       1 import pandas as pd
# ----> 2 redsdata=pd.read_csv("my_html_data_to_csv.csv")
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
plot_components_plotly(m, forecast)

# %%
fig1 = plot_plotly(m, forecast)
fig1.write_html("filez.html")
fig1.show()
